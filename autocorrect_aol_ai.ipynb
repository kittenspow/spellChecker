# %%
import re
import string
from collections import Counter
import numpy as np

# %% [markdown]
# **Read Dataset**

# %%
def read_corpus(filename):
  with open(filename, "r") as file:
    lines = file.readlines()
    words = []
    for line in lines:
      words += re.findall(r'\w+', line.lower())

  return words

# %%
words = read_corpus("./sastrawi.txt")
print(f"Jumlah kata di dalam corpus: {len(words)}")
# Out:
# Jumlah kata di dalam corpus: 30820

# %%
vocabs = set(words)
print(f"Jumlah kosakata unik: {len(vocabs)}")
# Out:
# Jumlah kosakata unik: 30173

# %%
word_counts = Counter(words)
print(word_counts["kuliah"])
# Out:
# 1

# %% [markdown]
# **Count the word's probability**
#
#
# **P(word) = C(word) / V**
#
#
# P(word): probability of the word
#
# C(word): number of times the word appears in the corpus
#
# V: total number of the word count in the corpus

# %%
total_word_count = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()}

# %%
print(word_probas["kuliah"])
# Out:
# 3.244646333549643e-05

# %% [markdown]
# Split a word into two components

# %%
def split(word):
  return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
print(split("apapun"))
# Out:
# [('', 'apapun'), ('a', 'papun'), ('ap', 'apun'), ('apa', 'pun'), ('apap', 'un'), ('apapu', 'n'), ('apapun', '')]

# %% [markdown]
# 1. **Insert** a letter

# %%
def insert(word):
  letters = string.ascii_lowercase
  return [l + c + r for l, r in split(word) for c in letters]

# %%
print(insert("abar"))
# Out:
# ['aabar', 'babar', 'cabar', 'dabar', 'eabar', 'fabar', 'gabar', 'habar', 'iabar', 'jabar', 'kabar', 'labar', 'mabar', 'nabar', 'oabar', 'pabar', 'qabar', 'rabar', 'sabar', 'tabar', 'uabar', 'vabar', 'wabar', 'xabar', 'yabar', 'zabar', 'aabar', 'abbar', 'acbar', 'adbar', 'aebar', 'afbar', 'agbar', 'ahbar', 'aibar', 'ajbar', 'akbar', 'albar', 'ambar', 'anbar', 'aobar', 'apbar', 'aqbar', 'arbar', 'asbar', 'atbar', 'aubar', 'avbar', 'awbar', 'axbar', 'aybar', 'azbar', 'abaar', 'abbar', 'abcar', 'abdar', 'abear', 'abfar', 'abgar', 'abhar', 'abiar', 'abjar', 'abkar', 'ablar', 'abmar', 'abnar', 'aboar', 'abpar', 'abqar', 'abrar', 'absar', 'abtar', 'abuar', 'abvar', 'abwar', 'abxar', 'abyar', 'abzar', 'abaar', 'ababr', 'abacr', 'abadr', 'abaer', 'abafr', 'abagr', 'abahr', 'abair', 'abajr', 'abakr', 'abalr', 'abamr', 'abanr', 'abaor', 'abapr', 'abaqr', 'abarr', 'abasr', 'abatr', 'abaur', 'abavr', 'abawr', 'abaxr', 'abayr', 'abazr', 'abara', 'abarb', 'abarc', 'abard', 'abare', 'abarf', 'abarg', 'abarh', 'abari', 'abarj', 'abark', 'abarl', 'abarm', 'abarn', 'abaro', 'abarp', 'abarq', 'abarr', 'abars', 'abart', 'abaru', 'abarv', 'abarw', 'abarx', 'abary', 'abarz']

# %% [markdown]
# 2. **Delete** a letter

# %%
def delete(word):
  return [l + r[1:] for l,r in split(word) if r]

# %%
print(delete("wwalaupun"))
# Out:
# ['walaupun', 'walaupun', 'wwlaupun', 'wwaaupun', 'wwalupun', 'wwalapun', 'wwalauun', 'wwalaupn', 'wwalaupu']

# %% [markdown]
# 3. **Swap** two adjacent letters

# %%
def swap(word):
  return [l + r[1] + r[0] + r[2:] for l, r in split(word) if len(r)>1]

# %%
print(swap("yagn"))
# Out:
# ['aygn', 'ygan', 'yang']

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %% [markdown]
# 4. **Replace** a letter to another

# %%
def replace(word):
  letters = string.ascii_lowercase
  return [l + c + r[1:] for l, r in split(word) if r for c in letters]

# %%
print(replace("vulan"))
# Out:
# ['aulan', 'bulan', 'culan', 'dulan', 'eulan', 'fulan', 'gulan', 'hulan', 'iulan', 'julan', 'kulan', 'lulan', 'mulan', 'nulan', 'oulan', 'pulan', 'qulan', 'rulan', 'sulan', 'tulan', 'uulan', 'vulan', 'wulan', 'xulan', 'yulan', 'zulan', 'valan', 'vblan', 'vclan', 'vdlan', 'velan', 'vflan', 'vglan', 'vhlan', 'vilan', 'vjlan', 'vklan', 'vllan', 'vmlan', 'vnlan', 'volan', 'vplan', 'vqlan', 'vrlan', 'vslan', 'vtlan', 'vulan', 'vvlan', 'vwlan', 'vxlan', 'vylan', 'vzlan', 'vuaan', 'vuban', 'vucan', 'vudan', 'vuean', 'vufan', 'vugan', 'vuhan', 'vuian', 'vujan', 'vukan', 'vulan', 'vuman', 'vunan', 'vuoan', 'vupan', 'vuqan', 'vuran', 'vusan', 'vutan', 'vuuan', 'vuvan', 'vuwan', 'vuxan', 'vuyan', 'vuzan', 'vulan', 'vulbn', 'vulcn', 'vuldn', 'vulen', 'vulfn', 'vulgn', 'vulhn', 'vulin', 'vuljn', 'vulkn', 'vulln', 'vulmn', 'vulnn', 'vulon', 'vulpn', 'vulqn', 'vulrn', 'vulsn', 'vultn', 'vulun', 'vulvn', 'vulwn', 'vulxn', 'vulyn', 'vulzn', 'vulaa', 'vulab', 'vulac', 'vulad', 'vulae', 'vulaf', 'vulag', 'vulah', 'vulai', 'vulaj', 'vulak', 'vulal', 'vulam', 'vulan', 'vulao', 'vulap', 'vulaq', 'vular', 'vulas', 'vulat', 'vulau', 'vulav', 'vulaw', 'vulax', 'vulay', 'vulaz']

# %% [markdown]
# **I. Level One Edit**

# %%
def edit1(word):
  return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(edit1("abgaimana"))
# Out:
# {'abgaimanp', 'ahgaimana', 'abgazimana', 'jbgaimana', 'abgaimanta', 'abgaimanai', 'abglaimana', 'abgaimanac', 'tabgaimana', 'abgkaimana', 'abgaicana', 'argaimana', 'abgakmana', 'sbgaimana', 'abgaipmana', 'abgaimanal', 'abgaimarna', 'agaimana', 'aogaimana', 'abgapmana', 'albgaimana', 'abgimana', 'abgaimayna', 'abgasimana', 'nabgaimana', 'acbgaimana', 'aobgaimana', 'abgaimara', 'absgaimana', 'abgaimaona', 'abegaimana', 'abgavimana', 'abggimana', 'abgaimaya', 'abgaimna', 'abgaimanz', 'dabgaimana', 'abgajimana', 'abgaiymana', 'abgsimana', 'abgaimanfa', 'abgaieana', 'abgaimaba', 'abgaamana', 'abgaimfana', 'abgaimada', 'rabgaimana', 'abgaimapa', 'abgaimanva', 'abgaimanxa', 'abgabimana', 'augaimana', 'qbgaimana', 'abgaumana', 'mbgaimana', 'abgaimanar', 'abgaiwmana', 'abgalimana', 'abgaimanwa', 'abgaimank', 'abgaixmana', 'aebgaimana', 'abgaimgana', 'abgaiemana', 'abgpimana', 'abgauimana', 'iabgaimana', 'abgafimana', 'abgaimxana', 'abgaimqna', 'abghimana', 'abgaimanq', 'abgaimant', 'ablgaimana', 'lbgaimana', 'mabgaimana', 'abgaimyana', 'abgaimans', 'abgaimanaj', 'abgvaimana', 'abgrimana', 'amgaimana', 'dbgaimana', 'abgaimmana', 'abgyaimana', 'aybgaimana', 'cbgaimana', 'ajgaimana', 'abgsaimana', 'abgaimanj', 'gbgaimana', 'abygaimana', 'ubgaimana', 'cabgaimana', 'wabgaimana', 'abzgaimana', 'abgacmana', 'abgaimanav', 'abgaipana', 'abgaimanat', 'akgaimana', 'abgaqmana', 'abgaiiana', 'abgaimavna', 'bgaimana', 'abgaimjna', 'abgaimuna', 'abgaimvana', 'abvgaimana', 'abgpaimana', 'abxaimana', 'anbgaimana', 'abzaimana', 'abgdaimana', 'zabgaimana', 'abgaimanga', 'abgaimava', 'abgaimanh', 'abkgaimana', 'abgaiamana', 'aibgaimana', 'abgazmana', 'aagaimana', 'abgaimzna', 'abgaifmana', 'abgaemana', 'abnaimana', 'abgnaimana', 'abgaimansa', 'abgaimanas', 'abgaiana', 'abggaimana', 'afgaimana', 'abguimana', 'abgaifana', 'abgaimaxa', 'abgaiqana', 'abgaimmna', 'abgaimata', 'arbgaimana', 'wbgaimana', 'abgaigana', 'abgadimana', 'abwgaimana', 'abqaimana', 'abgaimanza', 'abgaimawa', 'abgaibmana', 'abgasmana', 'abgaimaina', 'adgaimana', 'abgaimauna', 'abkaimana', 'abgaimsana', 'abgairmana', 'vabgaimana', 'abgcimana', 'abgaimanl', 'abgaimatna', 'awbgaimana', 'abgmaimana', 'abgaimanap', 'abgaaimana', 'abgaimiana', 'abgaimanra', 'asgaimana', 'abgaimanpa', 'abgaimabna', 'abgaimand', 'kabgaimana', 'abgaimzana', 'abgaimanja', 'abgaimanak', 'abgnimana', 'abgaimamna', 'abgaimany', 'abgaoimana', 'abgaimanam', 'abgiimana', 'abgzimana', 'abgaimanb', 'abgaimanae', 'abgaimanba', 'aboaimana', 'abgaismana', 'abgaimanan', 'abgaimanya', 'abtgaimana', 'abbaimana', 'abgaimlana', 'abgaimaqa', 'abgaimania', 'nbgaimana', 'abgaigmana', 'abgaimgna', 'abgaizmana', 'abgaimanaq', 'abgaimaaa', 'abgaimang', 'ambgaimana', 'gabgaimana', 'abgaimrana', 'abgailana', 'abgaimanr', 'abgainmana', 'ebgaimana', 'abgaimapna', 'aubgaimana', 'ibgaimana', 'abgjaimana', 'abcgaimana', 'abgaimanv', 'abgaimaha', 'aabgaimana', 'abgqaimana', 'abgaimwana', 'akbgaimana', 'abgaimena', 'abgqimana', 'abgatmana', 'abgaimbana', 'abcaimana', 'abgaimlna', 'abgaimano', 'abgdimana', 'abgawmana', 'abaaimana', 'abgaimqana', 'abgaimazna', 'sabgaimana', 'abgaimaana', 'aqbgaimana', 'abgaimpna', 'abgagmana', 'aggaimana', 'abgaimafa', 'abgmimana', 'abgayimana', 'abgaimtana', 'abgaimanax', 'ajbgaimana', 'abgaimanca', 'abghaimana', 'abgaimaxna', 'abgaimala', 'abgajmana', 'abfaimana', 'abgaimaga', 'abgawimana', 'abgaikmana', 'abgaibana', 'abgaimaoa', 'abpaimana', 'ablaimana', 'abiaimana', 'abagimana', 'abgafmana', 'abgainana', 'algaimana', 'abgaimpana', 'pbgaimana', 'abgaimaea', 'abgaimdana', 'abganimana', 'abgaimacna', 'abgaimfna', 'abgamana', 'uabgaimana', 'abgwaimana', 'abgamimana', 'abguaimana', 'acgaimana', 'fbgaimana', 'abgalmana', 'abgaijana', 'abgaimwna', 'abogaimana', 'abgaimina', 'aigaimana', 'abugaimana', 'abgaimasna', 'abgaimanqa', 'bbgaimana', 'zbgaimana', 'abgaitana', 'abjgaimana', 'abgaqimana', 'abgaimanau', 'abgaimanf', 'abgaimane', 'abgadmana', 'abgaimbna', 'babgaimana', 'abgzaimana', 'abgaimanx', 'agbgaimana', 'ab ...

# %% [markdown]
# **II. Level Two Edit**
#
# implement level one edit twice

# %%
def edit2(word):
  return set(e2 for e1 in edit1(word) for e2 in edit1(e1))

# %%
print(edit2("arunika"))
# Out:
# {'arunsija', 'arunykka', 'aruniuau', 'carumnika', 'alunikha', 'runivka', 'abrunikaa', 'xaruniuka', 'arunickai', 'aruznihka', 'daruniga', 'arunitak', 'arurnikah', 'aruncimka', 'awrunikac', 'arusniha', 'arusndika', 'arunjkqa', 'aruhikl', 'parugika', 'arcunikad', 'aruniat', 'aruniodka', 'arsnizka', 'arutiga', 'arvnikca', 'xruniyka', 'arvnikha', 'arunhiva', 'avunima', 'aruniaq', 'arunisyka', 'arunhmka', 'hrnnika', 'aurunjika', 'aruronika', 'atjrunika', 'mrueika', 'krunkia', 'arhunikra', 'arunmikpa', 'arunkirka', 'arunikkan', 'aruniikpa', 'aruuita', 'farnnika', 'arunipaw', 'aruniuar', 'darunikh', 'abuniks', 'iiunika', 'parunikas', 'cruniva', 'arunvieka', 'araunija', 'aruivka', 'ayunikh', 'fruniko', 'arunipav', 'zarunmka', 'cdarunika', 'acunikar', 'arudniku', 'arunikawv', 'arhnikia', 'arvniika', 'ahrunija', 'adcunika', 'arunsiua', 'azuvika', 'arunikeam', 'arunfiki', 'crunikas', 'akunikav', 'arpunka', 'aofrunika', 'aruniujka', 'arvunikoa', 'arunivf', 'arunizkaj', 'areunfika', 'hnarunika', 'iarunikaz', 'arunvkam', 'arunha', 'arunhiba', 'anuqika', 'aduneka', 'arunvgika', 'arxnikna', 'arukirka', 'axrunikh', 'jarunikj', 'afruynika', 'arulsika', 'aruwikia', 'arhurika', 'arumnibka', 'aruniykka', 'arfneka', 'orunikas', 'atruiika', 'trunikwa', 'arzuwika', 'brunifka', 'qjunika', 'afrunioa', 'arueiia', 'arunxika', 'arfnvka', 'arufniko', 'ajrubnika', 'akruniua', 'arnunikag', 'aruuik', 'aryeunika', 'aruciia', 'ajrujnika', 'rarfunika', 'arquniky', 'aronia', 'hrkunika', 'arunkicka', 'arkunikza', 'arumikn', 'aalunika', 'arunigia', 'vruniky', 'arunaha', 'arhnikxa', 'arunrkx', 'apunikja', 'dakrunika', 'laruncka', 'arufnkka', 'afrunrka', 'akunjika', 'vrunieka', 'arvnimka', 'crnnika', 'arunipkn', 'arunirkma', 'arudina', 'lrrnika', 'arwnikva', 'arwufnika', 'arzniak', 'arufnbka', 'arunemika', 'aruila', 'turnika', 'arlnipka', 'gacunika', 'fbarunika', 'aruvnikq', 'aaruneka', 'aurniska', 'atrbunika', 'koarunika', 'arpunik', 'airutnika', 'acunikj', 'arusngika', 'aqunikax', 'aruikba', 'srunikah', 'abunizka', 'arkuinika', 'ajarunika', 'oarunikae', 'aruineika', 'aerunikua', 'apruniko', 'aqunxka', 'arwonika', 'artunikoa', 'narunikd', 'aruaniaka', 'aronxka', 'aarjunika', 'lrunyka', 'arcnifka', 'arxnqka', 'ajrunilka', 'aruniskaq', 'marunikja', 'auunyika', 'arusikan', 'arubfka', 'arudniza', 'aruqeka', 'arunnikba', 'airuniea', 'avrunoka', 'aruuiska', 'arknlika', 'ybarunika', 'hbrunika', 'akuqika', 'aruninkv', 'oaprunika', 'larueika', 'aruniagk', 'aruwkika', 'abrunfika', 'arunikog', 'uadunika', 'arnunixa', 'arumniko', 'oarubika', 'artunima', 'xaprunika', 'aunirka', 'fargnika', 'anuenika', 'avrhunika', 'arunfrka', 'aguniak', 'aruniuba', 'mrunfka', 'crqnika', 'garunikq', 'aerunwka', 'arunmca', 'arioika', 'aerxunika', 'arwuniko', 'arunihksa', 'aroniia', 'asrpnika', 'atrunbika', 'arunnkai', 'argniika', 'arunidkap', 'arucniba', 'carynika', 'arunikacp', 'anunikoa', 'amunikda', 'wrunila', 'avruqnika', 'axunikla', 'trunikaa', 'arunigaf', 'arcnaika', 'narunbka', 'aruuiak', 'arunqkv', 'aruninkja', 'arunyiaa', 'acunikr', 'arunfiska', 'arsnpka', 'arunxikoa', 'maruinka', 'afunikva', 'arunijn', 'arunnqa', 'arunblka', 'arslunika', 'murunika', 'arufnwika', 'jaruniaka', 'aruenikan', 'xrunila', 'arugnifka', 'aaranika', 'aruhhika', 'arunuikwa', 'aluuika', 'aruxnuka', 'arunqxa', 'arnuioa', 'azuniqa', 'arukniea', 'arbuonika', 'aruniklaw', 'aruxikas', 'arunikyja', 'aphunika', 'agunikaq', 'arsniku', 'xarhnika', 'jarunikaj', 'ardulika', 'aruailka', 'jrueika', 'srusnika', 'arunihkqa', 'aranikak', 'aruivnika', 'brunrka', 'darqnika', 'bruneka', 'grunikas', 'axrunjka', 'arunbeka', 'axunikza', 'vadrunika', 'karunikp', 'zrunlka', 'arwuniwka', 'frcunika', 'farumnika', 'aruniykua', 'arynizka', 'yrunikwa', 'arqunikxa', 'uardunika', 'rarunwika', 'aguntika', 'frunikam', 'ajrunikaf', 'arunfya', 'amunitka', 'arunikaxa', 'barunikaj', 'arrnizka', 'irunvika', 'jcrunika', 'xacunika', 'arunbiwka', 'arkunikoa', 'drnunika', 'arunikqak', 'qruwnika', 'arunhky', 'azwrunika', 'aarounika', 'yarnunika', 'arpnila', ' ...

# %% [markdown]
# **Spelling Check Function**
#
# IF the word exists in the vocabulary, THEN the word is already corrected spelt.
#
# ELSE, get suggestions by edit1, edit2,or the word itself. Then filter suggestions by the vocabulary. Show a word with the highest probability

# %%
def correct_spelling(word, vocabulary, word_probabilities):
  if word in vocabulary:
    print(f"'{word}' sudah dieja dengan benar")
    return

  suggestions = edit1(word) or edit2(word) or [word]
  best_guesses = [w for w in suggestions if w in vocabulary]
  return [(w, word_probabilities[w]) for w in best_guesses]

# %%
def spellCheck(word):
  corrections = correct_spelling(word, vocabs, word_probas)

  if corrections:
    print(f"saran kosakata: {corrections}")
    probs = np.array([c[1] for c in corrections])
    best_ix = np.argmax(probs)
    correct = corrections[best_ix][0]
    print(f"kosakata dengan probabilitas terbesar: {correct}")
    print('')
    print(f"'{correct}' disarankan untuk '{word}'")

# %% [markdown]
# Let's try! 😸

# %%
spellCheck("masalh")
# Out:
# saran kosakata: [('masalah', 3.244646333549643e-05), ('masala', 3.244646333549643e-05)]
# kosakata dengan probabilitas terbesar: masalah
#
# 'masalah' disarankan untuk 'masalh'

# %%
spellCheck("atmosfir")
# Out:
# saran kosakata: [('atmosfer', 3.244646333549643e-05)]
# kosakata dengan probabilitas terbesar: atmosfer
#
# 'atmosfer' disarankan untuk 'atmosfir'

# %%
spellCheck("antre")
# Out:
# 'antre' sudah dieja dengan benar
